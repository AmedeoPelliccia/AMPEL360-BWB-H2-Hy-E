# %% [markdown]
# # Prototype Notebook Template
#
# ## 1. Setup
# Import libraries and configure environment.

# %%
# Import libraries
import numpy as np
import pandas as pd
import tensorflow as tf

# %% [markdown]
# ## 2. Load Data

# %% [markdown]
# ## 3. Train Model

# %% [markdown]
# ## 4. Evaluate

# %% [markdown]
# ## 5. Conclusions
